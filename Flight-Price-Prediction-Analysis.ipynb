# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Dataset using Pandas

# %%
df=pd.read_csv('Flight-price-prediction.csv')
df
# Out:
#        Unnamed: 0    airline     flight source_city departure_time stops  \
# 0               0   SpiceJet    SG-8709       Delhi        Evening  zero
# 1               1   SpiceJet    SG-8157       Delhi  Early_Morning  zero
# 2               2    AirAsia     I5-764       Delhi  Early_Morning  zero
# 3               3    Vistara     UK-995       Delhi        Morning  zero
# 4               4    Vistara     UK-963       Delhi        Morning  zero
# ...           ...        ...        ...         ...            ...   ...
# 10021       10021     Indigo  6.00E-186       Delhi      Afternoon   one
# 10022       10022  Air_India     AI-441       Delhi        Evening   one
# 10023       10023  Air_India     AI-665       Delhi  Early_Morning   one
# 10024       10024    Vistara     UK-933       Delhi      Afternoon   one
# 10025       10025    Vistara     UK-933       Delhi      Afternoon   one
#
#         arrival_time destination_city    class  duration  days_left  price
# ...

# %%
df.shape
# Out:
# (10026, 12)

# %% [markdown]
# #### This dataset has 10026 Rows and 12 columns

# %% [markdown]
# ### Displaying first 5 rows of dataset

# %%
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# ### Displaying last 5 rows of dataset.

# %%
df.tail()
# Out:
#        Unnamed: 0    airline     flight source_city departure_time stops  \
# 10021       10021     Indigo  6.00E-186       Delhi      Afternoon   one
# 10022       10022  Air_India     AI-441       Delhi        Evening   one
# 10023       10023  Air_India     AI-665       Delhi  Early_Morning   one
# 10024       10024    Vistara     UK-933       Delhi      Afternoon   one
# 10025       10025    Vistara     UK-933       Delhi      Afternoon   one
#
#       arrival_time destination_city    class  duration  days_left  price
# 10021        Night        Bangalore  Economy      7.42          1  11310
# 10022      Morning        Bangalore  Economy     17.33          1  11310
# 10023      Morning        Bangalore  Economy     27.17          1  11310
# 10024      Morning        Bangalore  Economy     19.25          1  12255
# 10025      Morning        Bangalore  Economy     17.33          1  12360

# %% [markdown]
# ### Checking what coulumns are there in dataset.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### Checking if the data has null values or not.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %% [markdown]
# ### Information about datatset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10026 entries, 0 to 10025
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        10026 non-null  int64
#  1   airline           10026 non-null  object
#  2   flight            10026 non-null  object
#  3   source_city       10026 non-null  object
#  4   departure_time    10026 non-null  object
#  5   stops             10026 non-null  object
#  6   arrival_time      10026 non-null  object
#  7   destination_city  10026 non-null  object
#  8   class             10026 non-null  object
#  9   duration          10026 non-null  float64
#  10  days_left         10026 non-null  int64
#  11  price             10026 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 940.1+ KB

# %% [markdown]
# ### Dimensions of Dataset

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ### Central location of data from df1.

# %%
df.mean()
# Out:
# C:\Users\deepu\AppData\Local\Temp\ipykernel_21400\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Unnamed: 0    5012.500000
# duration         9.545932
# days_left       25.806603
# price         6071.990026
# dtype: float64

# %% [markdown]
# ### Median value of a data set.

# %%
df.median()
# Out:
# C:\Users\deepu\AppData\Local\Temp\ipykernel_21400\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Unnamed: 0    5012.50
# duration         7.67
# days_left       26.00
# price         5321.00
# dtype: float64

# %% [markdown]
# ### Values that appear most often.

# %%
df.mode()
# Out:
#        Unnamed: 0  airline  flight source_city departure_time stops  \
# 0               0  Vistara  UK-819       Delhi        Evening   one
# 1               1      NaN     NaN         NaN            NaN   NaN
# 2               2      NaN     NaN         NaN            NaN   NaN
# 3               3      NaN     NaN         NaN            NaN   NaN
# 4               4      NaN     NaN         NaN            NaN   NaN
# ...           ...      ...     ...         ...            ...   ...
# 10021       10021      NaN     NaN         NaN            NaN   NaN
# 10022       10022      NaN     NaN         NaN            NaN   NaN
# 10023       10023      NaN     NaN         NaN            NaN   NaN
# 10024       10024      NaN     NaN         NaN            NaN   NaN
# 10025       10025      NaN     NaN         NaN            NaN   NaN
#
#       arrival_time destination_city    class  duration  days_left   price
# 0            Night           Mumbai  Economy      2.17       24.0  2410.0
# ...

# %% [markdown]
# ### How dispersed the data is in relation to the mean

# %%
df.std()
# Out:
# C:\Users\deepu\AppData\Local\Temp\ipykernel_21400\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Unnamed: 0    2894.401233
# duration         7.060023
# days_left       13.682783
# price         3783.692481
# dtype: float64

# %% [markdown]
# ### Statistical measurement of the spread between numbers

# %%
df.var()
# Out:
# C:\Users\deepu\AppData\Local\Temp\ipykernel_21400\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Unnamed: 0    8.377559e+06
# duration      4.984392e+01
# days_left     1.872186e+02
# price         1.431633e+07
# dtype: float64

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# #### Price variable

# %%
# describe the price variable in df.
df.price.describe()
# Out:
# count    10026.000000
# mean      6071.990026
# std       3783.692481
# min       2281.000000
# 25%       3102.000000
# 50%       5321.000000
# 75%       6756.000000
# max      31260.000000
# Name: price, dtype: float64

# %%
#plot the histogram of price variable.
df.price.plot.hist()
plt.show()

# %%
#plot the boxplot of price variable.
sns.boxplot(df.price)
plt.show()
# Out:
# C:\Users\deepu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### days_left variable

# %%
#describe the days_lest variable of df
df.days_left.describe()
# Out:
# count    10026.000000
# mean        25.806603
# std         13.682783
# min          1.000000
# 25%         14.000000
# 50%         26.000000
# 75%         38.000000
# max         49.000000
# Name: days_left, dtype: float64

# %%
#plot the boxplot of days_left variable.
sns.boxplot(df.days_left)
plt.show()
# Out:
# C:\Users\deepu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Duration variable

# %%
#describe the duration variable of inp1.
df.duration.describe()
# Out:
# count    10026.000000
# mean         9.545932
# std          7.060023
# min          2.000000
# 25%          2.330000
# 50%          7.670000
# 75%         13.750000
# max         30.080000
# Name: duration, dtype: float64

# %%
#plot the boxplot of duration variable.
sns.boxplot(df.duration)
plt.show()
# Out:
# C:\Users\deepu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plot the boxplot of duration variable after scaling in 8:2.
plt.figure(figsize=[8,2])
sns.boxplot(df.duration)
plt.show()
# Out:
# C:\Users\deepu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Standardizing values

# %%
#describe the duration variable of inp1
df.duration.describe()
# Out:
# count    10026.000000
# mean         9.545932
# std          7.060023
# min          2.000000
# 25%          2.330000
# 50%          7.670000
# 75%         13.750000
# max         30.080000
# Name: duration, dtype: float64

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical unordered univariate analysis

# %% [markdown]
# #### departure_time

# %%
#calculate the percentage of each departure_time category. 
df.departure_time.value_counts(normalize=True)
# Out:
# Evening          0.271793
# Early_Morning    0.217834
# Morning          0.202573
# Afternoon        0.185917
# Night            0.112607
# Late_Night       0.009276
# Name: departure_time, dtype: float64

# %%
#plot the bar graph of percentage departure_time categories
df.departure_time.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# #### airline

# %%
#calculate the percentage of each airline status category.
df.airline.value_counts(normalize=True)
# Out:
# Vistara      0.293736
# Air_India    0.261221
# Indigo       0.165869
# GO_FIRST     0.164971
# AirAsia      0.063635
# SpiceJet     0.050569
# Name: airline, dtype: float64

# %%
#plot the bar graph of percentage airline categories
df.airline.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ### Categorical ordered univariate analysis

# %% [markdown]
# #### airline

# %%
#calculate the percentage of each airline category.
df.airline.value_counts(normalize=True)
# Out:
# Vistara      0.293736
# Air_India    0.261221
# Indigo       0.165869
# GO_FIRST     0.164971
# AirAsia      0.063635
# SpiceJet     0.050569
# Name: airline, dtype: float64

# %%
#plot the pie chart of airline categories
df.airline.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# #### arrival_time

# %%
#calculate the percentage of each arrival_time category.
df.arrival_time.value_counts(normalize=True).plot.bar()
plt.show()

# %% [markdown]
# ### stops the target variable

# %%
#calculate the percentage of each stops category.
df.stops.value_counts(normalize=True)
# Out:
# one            0.732396
# zero           0.260323
# two_or_more    0.007281
# Name: stops, dtype: float64

# %%
#plot the pie chart of stops categories
df.stops.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# ### Bivariate and Multivariate Analysis

# %% [markdown]
# #### Numeric- numeric analysis

# %% [markdown]
# There are three ways to analyse the numeric- numeric data types simultaneously.
# - **Scatter plot**: describes the pattern that how one variable is varying with other variable.
# - **Correlation matrix**: to describe the linearity of two numeric variables.
# - **Pair plot**: group of scatter plots of all numeric variables in the data frame.

# %%
#plot the scatter plot of price and duration variable in df
plt.scatter(df.price, df.duration)
plt.show()

# %%
#plot the scatter plot of days_left and duration variable in df
df.plot.scatter(x="days_left", y="duration")
plt.show()

# %%
#plot the pair plot of price, duration and days_left in inp1 dataframe.
sns.pairplot(data=df,vars=["price","duration","days_left"])
plt.show()

# %% [markdown]
# ### Correlation heat map

# %%
#plot the correlation matrix of salary, balance and age in inp1 dataframe.
df[["days_left","price","duration"]].corr()
# Out:
#            days_left     price  duration
# days_left   1.000000 -0.546452 -0.040046
# price      -0.546452  1.000000  0.311061
# duration   -0.040046  0.311061  1.000000

# %%
sns.heatmap(df[["days_left","price","duration"]].corr(),annot=True,cmap="Reds")
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(28,8))
corr = df.corr()
sns.heatmap(corr,annot=True,
           xticklabels = corr.columns.values,
           yticklabels = corr.columns.values);
plt.show()

# %%
sns.pairplot(df,hue="source_city",size=3)
# Out:
# C:\Users\deepu\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
